# %% [markdown]
# <a href="https://colab.research.google.com/github/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/blob/main/PERFORMANCE_LINEAR_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as matlab
import statsmodels

# %% [markdown]
# # ***Correlation***

# %%
import pandas as pd
import numpy as np

# Load your dataset from GitHub
air = pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/refs/heads/main/New_Atm_Para.csv")

air.info()  # Check data details

# Display first few rows for inspection
air.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Altitude              86 non-null     int64
#  1   Temperature           86 non-null     float64
#  2   Pressure              86 non-null     float64
#  3   Density               86 non-null     float64
#  4   Mach_Number           86 non-null     float64
#  5   Gravity               86 non-null     float64
#  6   Kinematic_Viscosity   86 non-null     float64
#  7   Relative_Humidity     86 non-null     float64
#  8   Wind_Gust             86 non-null     float64
#  9   Turbulence_Intensity  86 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 6.8 KB
#    Altitude  Temperature      Pressure   Density  Mach_Number   Gravity  \
# 0         0       288.15  101325.00000  1.225226     0.734727  9.806650
# ...

# %%
#Find the correlation between Altitude & pressure.
np.corrcoef(air.Altitude, air.Pressure)
# Out:
# array([[ 1.        , -0.99323253],
#        [-0.99323253,  1.        ]])

# %%
# -------------------------------------------------------------
# Find correlations between selected atmospheric parameters
# -------------------------------------------------------------

# 1. Altitude vs Temperature
corr_alt_temp = np.corrcoef(air.Altitude, air.Temperature)
print(f"Correlation between Altitude and Temperature:\n {corr_alt_temp}")

# 2. Pressure vs Density
corr_press_dens = np.corrcoef(air.Pressure, air.Density)[0,1]
# [0,1] extracts the correlation between the two variables.
print(f"Correlation between Pressure and Density: {corr_press_dens:.3f}")

# 3. Turbulence_Intensity vs Kinematic Viscosity
corr_mach_nu = np.corrcoef(air.Turbulence_Intensity, air.Kinematic_Viscosity)[0,1]
print(f"Correlation between Turbulence_Intensity and Kinematic Viscosity: {corr_mach_nu:.3f}")
# Out:
# Correlation between Altitude and Temperature:
#  [[ 1. -1.]
#  [-1.  1.]]
# Correlation between Pressure and Density: 1.000
# Correlation between Turbulence_Intensity and Kinematic Viscosity: 0.083

# %%
# -------------------------------------------------------------
# Optional: Display correlation matrix for all numerical features
# -------------------------------------------------------------
print("\nFull Correlation Matrix:")
print(air.corr().round(3))
# Computes the correlation matrix between all numerical columns in the DataFrame air.
# Rounds each correlation value to 3 decimal places for neat output.
# Out:
# Full Correlation Matrix:
#                       Altitude  Temperature  Pressure  Density  Mach_Number  \
# Altitude                 1.000       -1.000    -0.993   -0.996        0.999
# Temperature             -1.000        1.000     0.993    0.996       -0.999
# Pressure                -0.993        0.993     1.000    1.000       -0.988
# Density                 -0.996        0.996     1.000    1.000       -0.991
# Mach_Number              0.999       -0.999    -0.988   -0.991        1.000
# Gravity                 -1.000        1.000     0.993    0.996       -0.999
# Kinematic_Viscosity      0.993       -0.993    -0.972   -0.978        0.997
# Relative_Humidity        0.034       -0.034    -0.020   -0.024        0.038
# Wind_Gust               -0.035        0.035     0.036    0.035       -0.035
# Turbulence_Intensity     0.077       -0.077    -0.072   -0.073        0.079
#
#                       Gravity  Kinematic_Viscosity  Relative_Humidity  \
# ...

# %% [markdown]
# # ***REGRESSION***

# %%
import pandas as pd
import statsmodels.formula.api as sm

# Load your dataset
air = pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/main/New_Atm_Para.csv")

# 1. Model 1: Altitude vs Density

model1 = sm.ols(formula='Density ~ Altitude', data=air)
fitted1 = model1.fit()
print("\nRegression Summary: Altitude vs Density")
print(fitted1.summary())
# Out:
# Regression Summary: Altitude vs Density
#                             OLS Regression Results
# ...
# Dep. Variable:                Density   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.044e+04
# Date:                Mon, 15 Dec 2025   Prob (F-statistic):           6.85e-90
# Time:                        11:30:46   Log-Likelihood:                 218.68
# No. Observations:                  86   AIC:                            -433.4
# Df Residuals:                      84   BIC:                            -428.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1822      0.004    287.154      0.000       1.174       1.190
# ...

# %% [markdown]
# # **PREDICTION**

# %%
#b0 ==> Intercept  ==>
#b1 ===> coeff -altitude ==>

# y = b0 +b1*x
# density = 1.1822 + (-8*10^-5) * (altiude)
# altitude = 9872 m ==> density ?

# 1.1822 + (-8.545*10^-5) * (9872)
# 0.33386


import pandas as pd

# Create a new data point for prediction
new_data = pd.DataFrame({'Altitude': [9872]})

# Use your previously fitted model (fitted1)
predicted_density = fitted1.predict(new_data)

print("\nPredicted Density at 9872 m:")
print(predicted_density)

# %% [markdown]
# ## ***R Squared***

# %%
import pandas as pd
import statsmodels.formula.api as sm

# Load dataset
air = pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/main/New_Atm_Para.csv")

# 1. Model 1: Altitude vs Density

model1 = sm.ols(formula='Density ~ Altitude', data=air)
fitted1 = model1.fit()
print("\nRegression Summary: Altitude vs Density")
print(fitted1.summary())


# 2. Model 2: Density vs Temperature

model2 = sm.ols(formula='Density ~ Temperature', data=air)
fitted2 = model2.fit()
print("\nRegression Summary: Density vs Temperature")
print(fitted2.summary())


# 3. Model 3: Density vs Pressure

model3 = sm.ols(formula='Density ~ Pressure', data=air)
fitted3 = model3.fit()
print("\nRegression Summary: Density vs Pressure")
print(fitted3.summary())


# 4. Model 4: Density vs Wind_Gust

model4 = sm.ols(formula='Density ~ Wind_Gust', data=air)
fitted4 = model4.fit()
print("\nRegression Summary: Density vs Wind_Gust")
print(fitted4.summary())


# prediction through diffrent model
# below value taken from ISA

# Altitude      =  8900
# Temperature   =   230.3
# Pressure      = 31195.25
# Wind_Gust     = 11.43
# Density       = 0.47197

# Predict Density for Altitude = 8900 m
new_data1 = pd.DataFrame({'Altitude': [8900]})
pred1 = fitted1.predict(new_data1)
print(f"\nPredicted Density at 8900 m Altitude: {pred1[0]:.4f} kg/m³")

# Predict Density for Temperature = 230.3 K
new_data2 = pd.DataFrame({'Temperature': [230.3]})
pred2 = fitted2.predict(new_data2)
print(f"\nPredicted Density at Temperature 230.3 K: {pred2[0]:.4f} kg/m³")

# Predict Density for Pressure = 31195.25 Pa
new_data3 = pd.DataFrame({'Pressure': [31195.25]})
pred3 = fitted3.predict(new_data3)
print(f"\nPredicted Density at Pressure 31195.25 Pa: {pred3[0]:.4f} kg/m³")

# Predict Density for Wind_Gust = 11.43 m/s
new_data4 = pd.DataFrame({'Wind_Gust': [11.43]})
pred4 = fitted4.predict(new_data4)
print(f"\nPredicted Density at Wind Gust 11.43 m/s: {pred4[0]:.4f} kg/m³")

# %% [markdown]
# # ***Multiple Regerssion Model***

# %%
import pandas as pd
import statsmodels.formula.api as sm

# Load your dataset
air = pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/main/New_Atm_Para.csv")

# Multi-linear regression: Density predicted from multiple features
model = sm.ols(formula='Density ~ Altitude + Temperature + + Pressure + Mach_Number + Relative_Humidity + Wind_Gust + Turbulence_Intensity', data=air)
fitted = model.fit()
print("\nMultiple Regression Summary: Density ~ Altitude + Temperature + Pressure + Mach_Number + Relative_Humidity + Wind_Gust + Turbulence_Intensity")
print(fitted.summary())

# %% [markdown]
# # **Individual variables impact**

# %%
import pandas as pd
import statsmodels.formula.api as sm

# Load your dataset
air = pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/main/New_Atm_Para.csv")

# p-value..find p value and drop the variables
model = sm.ols(formula='Density ~ Altitude + Temperature + Pressure + Mach_Number ', data=air)
fitted = model.fit()
print("\nMultiple Regression Summary: Density ~ Altitude + Temperature + Pressure + Mach_Number ")
print(fitted.summary())

# %% [markdown]
# # ***Adjusted R-Square***

# %%
adj_sample=pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/ML-DL/refs/heads/main/Adj_r_square_Sample.csv")

#Build a model to predict y using x1,x2 and x3. Note down R-Square and Adj R-Square values

#model 1

model = sm.ols(formula='Y ~ x1+x2+x3', data=adj_sample)
fitted = model.fit()
print(fitted.summary())


#Model2
model = sm.ols(formula='Y ~ x1+x2+x3+x4+x5+x6', data=adj_sample)
fitted = model.fit()
print(fitted.summary())

#Model3
model = sm.ols(formula='Y ~ x1+x2+x3+x4+x5+x6+x7+x8', data=adj_sample)
fitted = model.fit()
print(fitted.summary())

# %%
import pandas as pd
import statsmodels.formula.api as smf

# Load the dataset
data = pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/refs/heads/main/VIF.csv")

# Build the regression model
model = smf.ols(formula='Avg_thrust ~ Combustion_temp+Exhaust_velocity+ percentage_of_mdota+ percentage_of_mdotf', data=data)

# Fit the model
fitted = model.fit()

# Display the regression summary
print(fitted.summary())

# %% [markdown]
# # ***Model After dropping Combustion_temp***

# %%
# regression model dropping combustion_temp
model = smf.ols(formula='Avg_thrust ~ Exhaust_velocity+ percentage_of_mdota+ percentage_of_mdotf', data=data)

# Fit the model
fitted1 = model.fit()

# Display the regression summary
print(fitted1.summary())

# %% [markdown]
# # ***Model After dropping exhaust velocity***

# %%
# regression model dropping exhaust velocity
model = smf.ols(formula='Avg_thrust ~ Combustion_temp+ percentage_of_mdota+ percentage_of_mdotf', data=data)

# Fit the model
fitted1 = model.fit()

# Display the regression summary
print(fitted1.summary())

# %% [markdown]
# # ***VIF***

# %%
#Code for VIF Calculation
#Writing a function to calculate the VIF values
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# -------------------------------------------------------------
# Load and clean dataset
# -------------------------------------------------------------
data = pd.read_csv("https://raw.githubusercontent.com/cmvigneswaranaero-gif/AC_PERFROMANCE_WITH_ML/refs/heads/main/VIF.csv")
data.columns = data.columns.str.strip()  # remove extra spaces

# Select input features (independent variables)
X_Data = data[['Combustion_temp', 'Exhaust_velocity', 'percentage_of_mdota', 'percentage_of_mdotf']]

# -------------------------------------------------------------
# Function to calculate VIF
# -------------------------------------------------------------
def vif_cal(input_data):
    X_with_const = sm.add_constant(input_data)   # add intercept
    vif_data = pd.DataFrame()
    vif_data["Feature"] = X_with_const.columns
    vif_data["VIF"] = [variance_inflation_factor(X_with_const.values, i)
                       for i in range(X_with_const.shape[1])]
    return vif_data

# -------------------------------------------------------------
# Calculate VIF for all variables
# -------------------------------------------------------------
print("VIF for all variables:")
print(vif_cal(input_data=X_Data))

# %%
print("\nVIF after dropping 'Combustion_temp':")
print(vif_cal(input_data=X_Data.drop(["Combustion_temp"], axis=1)))

# %%
print("\n VIF after dropping 'Combustion_temp' and 'percentage_of_mdotf':")
print(vif_cal(input_data=X_Data.drop(['Combustion_temp', 'percentage_of_mdotf'], axis=1)))

# %%
# regression model dropping combustion_temp & percentage_of_mdotf
model = smf.ols(formula='Avg_thrust ~ Exhaust_velocity+ percentage_of_mdota', data=data)

# Fit the model
fitted2 = model.fit()

# Display the regression summary
print(fitted2.summary())

# %% [markdown]
# # ***export excel***

# %%
import numpy as np
from openpyxl import Workbook
from openpyxl.utils import get_column_letter
from google.colab import files

# ----- Inputs -----
S_list  = [17, 34, 47, 85, 103]
b_list  = [17.47, 33.0, 54.0, 24.0, 40]
Cd0_list = [0.032, 0.051, 0.10]
e_list   = [0.87, 0.77, 0.93]
Weight = np.arange(50000, 200001, 10000)
rho_vals = [1.225, 1.112, 1.007, 0.819, 0.525, 0.413]
V_vals   = np.linspace(30, 300, 50)
TA0 = 80596.0

# ----- Workbook -----
wb = Workbook()
ws = wb.active
ws.title = "Aero Data"

# Header
ws.append([
    "rho","W","V","S","b","AR","Cd0","e",
    "CL","CD","CL/CD",
    "TR","PR","TA","PA","RC"
])

row = 2  # Excel row index

for S, b in zip(S_list, b_list):
    AR = b*b/S

    for Cd0, e in zip(Cd0_list, e_list):
        k = 1/(np.pi * e * AR)

        for W in Weight:
            for r in rho_vals:
                for V in V_vals:

                    # Compute numeric values (to DISPLAY)
                    q  = 0.5 * r * V**2
                    CL_val = W/(q*S)
                    CD_val = Cd0 + k*CL_val**2
                    TR_val = q*S*CD_val
                    PR_val = TR_val * V
                    TA_val = (r/1.225)*TA0
                    PA_val = TA_val * V
                    RC_val = (PA_val - PR_val)/W
                    CLCD_val = CL_val / CD_val

                    # ----- Write DISPLAY values -----
                    ws.cell(row=row, column=1, value=r)
                    ws.cell(row=row, column=2, value=W)
                    ws.cell(row=row, column=3, value=V)
                    ws.cell(row=row, column=4, value=S)
                    ws.cell(row=row, column=5, value=b)
                    ws.cell(row=row, column=6, value=AR)
                    ws.cell(row=row, column=7, value=Cd0)
                    ws.cell(row=row, column=8, value=e)
                    ws.cell(row=row, column=9, value=CL_val)
                    ws.cell(row=row, column=10, value=CD_val)
                    ws.cell(row=row, column=11, value=CLCD_val)
                    ws.cell(row=row, column=12, value=TR_val)
                    ws.cell(row=row, column=13, value=PR_val)
                    ws.cell(row=row, column=14, value=TA_val)
                    ws.cell(row=row, column=15, value=PA_val)
                    ws.cell(row=row, column=16, value=RC_val)

                    # ----- Attach the formula so Excel shows it in formula bar -----
                    # (Replace A,B,C.. with actual cell coordinates)
                    rho_c = f"A{row}"
                    W_c   = f"B{row}"
                    V_c   = f"C{row}"
                    S_c   = f"D{row}"
                    Cd0_c = f"G{row}"

                    # Store formulas but keep display values
                    ws[f"I{row}"].value  = f"={W_c}/(0.5*{rho_c}*{V_c}*{V_c}*{S_c})"   # CL
                    ws[f"J{row}"].value  = f"={Cd0_c}+({CL_val}*{CL_val})*{k}"          # CD
                    ws[f"K{row}"].value  = f"=I{row}/J{row}"                             # CL/CD
                    ws[f"L{row}"].value  = f"=0.5*{rho_c}*{V_c}*{V_c}*{S_c}*J{row}"       # TR
                    ws[f"M{row}"].value  = f"=L{row}*{V_c}"                               # PR
                    ws[f"N{row}"].value  = f"=({r}/1.225)*{TA0}"                          # TA
                    ws[f"O{row}"].value  = f"=N{row}*{V_c}"                               # PA
                    ws[f"P{row}"].value  = f"=(O{row}-M{row})/{W_c}"                      # RC

                    row += 1

# Save file
filename = "Aero_Results_With_Formulas.xlsx"
wb.save(filename)

# Download in Colab
files.download(filename)
